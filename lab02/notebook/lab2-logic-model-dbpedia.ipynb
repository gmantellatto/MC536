# %% [markdown]
# # Laboratório 2

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"

concept = "Tent_of_Miracles_(novel)"
format = "jsod"

concept = concept.replace(" ", "_")

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
js = data.json()
print(json.dumps(js, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
autor = js["d"]["results"][0]["http://dbpedia.org/ontology/author"]["__deferred"]["uri"]
print("O autor de Tenda dos Milagres é: " + autor)
# Out:
# O autor de Tenda dos Milagres é: http://dbpedia.org/resource/Jorge_Amado

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

concept = "Aspirin"
match = "exact"
limit = "10"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()
print(json.dumps(json_mi, indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/D001241",
#       "label": "Aspirin"
#    }
# ]

# %% [markdown]
# **Acessando os códigos do recurso:**

# %%
uri_mesh = json_mi[0]["resource"]
print("uri do recurso: " + uri_mesh)
bar = str.rindex(uri_mesh, "/")
print("código do recurso: " + uri_mesh[bar+1:])
# Out:
# uri do recurso: http://id.nlm.nih.gov/mesh/D001241
# código do recurso: D001241

# %% [markdown]
# **Acessando detalhes a partir do código**

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/details?descriptor={code}"

code = uri_mesh[bar+1:]

url = url_template.replace("{code}", code)

data = requests.get(url)
json_mid = data.json()
print(json.dumps(json_mid, indent=3))
# Out:
# {
#    "descriptor": "http://id.nlm.nih.gov/mesh/D001241",
#    "terms": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003713",
#          "label": "Aspirin",
#          "preferred": true
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003714",
#          "label": "2-(Acetyloxy)benzoic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003712",
#          "label": "Acetylsalicylic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003721",
#          "label": "Acetysal",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003722",
#          "label": "Acylpyrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003711",
#          "label": "Aloxiprimum",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003723",
#          "label": "Colfarit",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003715",
#          "label": "Dispril",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003719",
#          "label": "Easprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003724",
#          "label": "Ecotrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003725",
#          "label": "Endosprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003726",
#          "label": "Magnecyl",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003727",
#          "label": "Micristin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003717",
#          "label": "Polopirin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003728",
#          "label": "Polopiryna",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003716",
#          "label": "Solprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003718",
#          "label": "Solupsan",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003720",
#          "label": "Zorprin",
#          "preferred": false
#       }
#    ],
#    "qualifiers": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000008",
#          "label": "administration & dosage"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000009",
#          "label": "adverse effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000819",
#          "label": "agonists"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000031",
#          "label": "analogs & derivatives"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000032",
#          "label": "analysis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000037",
#          "label": "antagonists & inhibitors"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000097",
#          "label": "blood"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000134",
#          "label": "cerebrospinal fluid"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000138",
#          "label": "chemical synthesis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000737",
#          "label": "chemistry"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000145",
#          "label": "classification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000191",
#          "label": "economics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000266",
#          "label": "history"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000276",
#          "label": "immunology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000302",
#          "label": "isolation & purification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000378",
#          "label": "metabolism"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000493",
#          "label": "pharmacokinetics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000494",
#          "label": "pharmacology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000506",
#          "label": "poisoning"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000528",
#          "label": "radiation effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000592",
#          "label": "standards"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000600",
#          "label": "supply & distribution"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000627",
#          "label": "therapeutic use"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000633",
#          "label": "toxicity"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000652",
#          "label": "urine"
#       }
#    ],
#    "seealso": []
# }

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Pentagon"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
office_ref = data.json()
print(json.dumps(office_ref, indent=3))
# Out:
# [
#    {
#       "place_id": 256879358,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "relation",
#       "osm_id": 89605,
#       "boundingbox": [
#          "38.8688653",
#          "38.8729407",
#          "-77.0584346",
#          "-77.0531862"
#       ],
#       "lat": "38.87089315",
#       "lon": "-77.05450712189227",
#       "display_name": "Pentagon, Pentagon Access Road, Pentagon City, Arlington, Arlington County, Virginia, 20310, United States",
#       "class": "military",
#       "type": "office",
#       "importance": 0.6766738092909717
#    },
#    {
#       "place_id": 322672714,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "relation",
#       "osm_id": 12864376,
#       "boundingbox": [
#          "50.8326563",
#          "50.8583568",
#          "4.338056",
#          "4.3691398"
#       ],
#       "lat": "50.8482953",
#       "lon": "4.3496311",
#       "display_name": "Pentagone - Vijfhoek, Bruxelles - Brussel, Ville de Bruxelles - Stad Brussel, Brussel-Hoofdstad - Bruxelles-Capitale, R\u00e9gion de Bruxelles-Capitale - Brussels Hoofdstedelijk Gewest, 1000, Belgi\u00eb / Belgique / Belgien",
#       "class": "place",
#       "type": "suburb",
#       "importance": 0.49077155677239526,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 4155719,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 453069888,
#       "boundingbox": [
#          "38.8641306",
#          "38.8741306",
#          "-77.059076",
#          "-77.049076"
#       ],
#       "lat": "38.8691306",
#       "lon": "-77.054076",
#       "display_name": "Pentagon, Pentagon Access Road, Pentagon City, Arlington, Arlington County, Virginia, 20310, United States",
#       "class": "railway",
#       "type": "station",
#       "importance": 0.4454292618867608,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//transport_train_station2.p.20.png"
#    },
#    {
#       "place_id": 61364307,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 5421094460,
#       "boundingbox": [
#          "59.6509889",
#          "59.6709889",
#          "10.7601583",
#          "10.7801583"
#       ],
#       "lat": "59.6609889",
#       "lon": "10.7701583",
#       "display_name": "Pentagon, Land\u00e5s, \u00c5s, Viken, 1433, Norge",
#       "class": "place",
#       "type": "quarter",
#       "importance": 0.36
#    },
#    {
#       "place_id": 42290450,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 3178279024,
#       "boundingbox": [
#          "-22.8528",
#          "-22.8328",
#          "147.7323375",
#          "147.7523375"
#       ],
#       "lat": "-22.8428",
#       "lon": "147.7423375",
#       "display_name": "Pentagon, Clermont, Isaac Regional, Queensland, Australia",
#       "class": "place",
#       "type": "farm",
#       "importance": 0.30999999999999994
#    },
#    {
#       "place_id": 71904746,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 6423555571,
#       "boundingbox": [
#          "48.4158921",
#          "48.4558921",
#          "22.6821956",
#          "22.7221956"
#       ],
#       "lat": "48.4358921",
#       "lon": "22.7021956",
#       "display_name": "\u041f\u0435\u043d\u0442\u0430\u0433\u043e\u043d, \u041c\u0443\u043a\u0430\u0447\u0435\u0432\u043e, \u041c\u0443\u043a\u0430\u0447\u0456\u0432\u0441\u044c\u043a\u0430 \u043c\u0456\u0441\u044c\u043a\u0430 \u0433\u0440\u043e\u043c\u0430\u0434\u0430, \u041c\u0443\u043a\u0430\u0447\u0456\u0432\u0441\u044c\u043a\u0438\u0439 \u0440\u0430\u0439\u043e\u043d, \u0417\u0430\u043a\u0430\u0440\u043f\u0430\u0442\u0441\u044c\u043a\u0430 \u043e\u0431\u043b\u0430\u0441\u0442\u044c, 89601, \u0423\u043a\u0440\u0430\u0457\u043d\u0430",
#       "class": "place",
#       "type": "suburb",
#       "importance": 0.275,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 232694995,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 716814492,
#       "boundingbox": [
#          "54.9130093",
#          "54.9154945",
#          "61.454258",
#          "61.4599684"
#       ],
#       "lat": "54.9141085",
#       "lon": "61.4573935",
#       "display_name": "\u041f\u0435\u043d\u0442\u0430\u0433\u043e\u043d, \u0420\u043e\u0437\u0430, \u0420\u043e\u0437\u0438\u043d\u0441\u043a\u043e\u0435 \u0433\u043e\u0440\u043e\u0434\u0441\u043a\u043e\u0435 \u043f\u043e\u0441\u0435\u043b\u0435\u043d\u0438\u0435, \u041a\u043e\u0440\u043a\u0438\u043d\u0441\u043a\u0438\u0439 \u0440\u0430\u0439\u043e\u043d, \u0427\u0435\u043b\u044f\u0431\u0438\u043d\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c, \u0423\u0440\u0430\u043b\u044c\u0441\u043a\u0438\u0439 \u0444\u0435\u0434\u0435\u0440\u0430\u043b\u044c\u043d\u044b\u0439 \u043e\u043a\u0440\u0443\u0433, 456543, \u0420\u043e\u0441\u0441\u0438\u044f",
#       "class": "place",
#       "type": "suburb",
#       "importance": 0.275,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 74895446,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 6904456995,
#       "boundingbox": [
#          "43.3820831",
#          "43.4020831",
#          "42.911434",
#          "42.931434"
#       ],
#       "lat": "43.3920831",
#       "lon": "42.921434",
#       "display_name": "\u041f\u0435\u043d\u0442\u0430\u0433\u043e\u043d, \u0422\u044b\u0440\u043d\u044b\u0430\u0443\u0437, \u0433\u043e\u0440\u043e\u0434\u0441\u043a\u043e\u0435 \u043f\u043e\u0441\u0435\u043b\u0435\u043d\u0438\u0435 \u0422\u044b\u0440\u043d\u044b\u0430\u0443\u0437, \u042d\u043b\u044c\u0431\u0440\u0443\u0441\u0441\u043a\u0438\u0439 \u0440\u0430\u0439\u043e\u043d, \u041a\u0430\u0431\u0430\u0440\u0434\u0438\u043d\u043e-\u0411\u0430\u043b\u043a\u0430\u0440\u0438\u044f, \u0421\u0435\u0432\u0435\u0440\u043e-\u041a\u0430\u0432\u043a\u0430\u0437\u0441\u043a\u0438\u0439 \u0444\u0435\u0434\u0435\u0440\u0430\u043b\u044c\u043d\u044b\u0439 \u043e\u043a\u0440\u0443\u0433, 361624, \u0420\u043e\u0441\u0441\u0438\u044f",
#       "class": "place",
#       "type": "neighbourhood",
#       "importance": 0.25
#    },
#    {
#       "place_id": 80531467,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 7535484962,
#       "boundingbox": [
#          "48.4810966",
#          "48.5010966",
#          "35.9244898",
#          "35.9444898"
#       ],
#       "lat": "48.4910966",
#       "lon": "35.9344898",
#       "display_name": "\u041f\u0435\u043d\u0442\u0430\u0433\u043e\u043d, \u041f\u0417\u0422\u041e, \u041f\u0430\u0432\u043b\u043e\u0433\u0440\u0430\u0434, \u041f\u0430\u0432\u043b\u043e\u0433\u0440\u0430\u0434\u0441\u044c\u043a\u0430 \u043c\u0456\u0441\u044c\u043a\u0430 \u0433\u0440\u043e\u043c\u0430\u0434\u0430, \u041f\u0430\u0432\u043b\u043e\u0433\u0440\u0430\u0434\u0441\u044c\u043a\u0438\u0439 \u0440\u0430\u0439\u043e\u043d, \u0414\u043d\u0456\u043f\u0440\u043e\u043f\u0435\u0442\u0440\u043e\u0432\u0441\u044c\u043a\u0430 \u043e\u0431\u043b\u0430\u0441\u0442\u044c, 51413, \u0423\u043a\u0440\u0430\u0457\u043d\u0430",
#       "class": "place",
#       "type": "neighbourhood",
#       "importance": 0.25
#    },
#    {
#       "place_id": 52375749,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 4409469113,
#       "boundingbox": [
#          "-16.3771858",
#          "-16.3571858",
#          "126.1802978",
#          "126.2002978"
#       ],
#       "lat": "-16.3671858",
#       "lon": "126.1902978",
#       "display_name": "The Pentagon, Gibb, Shire Of Wyndham-East Kimberley, Western Australia, Australia",
#       "class": "place",
#       "type": "locality",
#       "importance": 0.225,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    }
# ]

# %% [markdown]
# ### Extraindo o identificador OSM

# %%
print(office_ref[0]["osm_id"])
# Out:
# 89605

# %% [markdown]
# ### REST API do OpenStreetMap para Elementos (Node, Way e Relation)

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "relation" # types: node, way, or relation
id = str(office_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
office_rel = data.json()
print(json.dumps(office_rel, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (703013 spike-07.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "relation",
#          "id": 89605,
#          "timestamp": "2021-06-30T10:56:16Z",
#          "version": 30,
#          "changeset": 107201252,
#          "user": "vvoovv",
#          "uid": 27371,
#          "members": [
#             {
#                "type": "way",
#                "ref": 8821713,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 28315757,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44924512,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44924514,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44924501,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44924504,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44924506,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44924507,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44924509,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44924490,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44924492,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44924493,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44924495,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44924497,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44925036,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44925037,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44930551,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44930534,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44930545,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44930546,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44930549,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 44930550,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 46823731,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 46823733,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 46823734,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 46823725,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 46823727,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 46823728,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 46823729,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 346665491,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 46823730,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 46823720,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 46823721,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 46823722,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 46823723,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 46823724,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 46823714,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 46823715,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 46823717,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 46823718,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 46823719,
#                "role": "inner"
#             },
#             {
#                "type": "way",
#                "ref": 346665490,
#                "role": "inner"
#             }
#          ],
#          "tags": {
#             "access": "private",
#             "building": "military",
#             "building:colour": "#F5DEB3",
#             "building:levels": "4",
#             "building:part": "yes",
#             "government": "yes",
#             "height": "23",
#             "image": "https://commons.wikimedia.org/wiki/File:The_Pentagon_January_2008.jpg",
#             "military": "office",
#             "military_service": "joint",
#             "name": "Pentagon",
#             "name:ar": "\u0628\u0646\u062a\u0627\u063a\u0648\u0646",
#             "name:bn": "\u09aa\u09c7\u09a8\u09cd\u099f\u09be\u0997\u09a8",
#             "name:en": "Pentagon",
#             "name:hi": "\u092a\u0947\u0902\u091f\u093e\u0917\u0928",
#             "name:it": "Il Pentagono",
#             "name:ja": "\u30da\u30f3\u30bf\u30b4\u30f3",
#             "name:ko": "\ud39c\ud0c0\uace4",
#             "name:ru": "\u041f\u0435\u043d\u0442\u0430\u0433\u043e\u043d",
#             "name:uk": "\u041f\u0435\u043d\u0442\u0430\u0433\u043e\u043d",
#             "name:zh": "\u4e94\u89d2\u5927\u697c",
#             "office": "government",
#             "operator": "United States Department of Defense",
#             "phone": "(703) 697-1776",
#             "roof:colour": "#4C4646",
#             "roof:shape": "flat",
#             "type": "multipolygon",
#             "website": "https://pentagontours.osd.mil/",
#             "wikidata": "Q11208",
#             "wikipedia": "en:The Pentagon"
#          }
#       }
#    ]
# }

# %% [markdown]
# ### Extraindo o Identificador DBPedia

# %%
print(office_rel["elements"][0]["tags"]["wikipedia"])
# Out:
# en:The Pentagon

# %% [markdown]
# ### REST API do DBPedia

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"
concept = office_rel["elements"][0]["tags"]["wikipedia"].replace(" ", "_")\
                                                        .replace("en:", "")
format = "jsod"

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
office_dbpedia = data.json()
print(json.dumps(office_dbpedia, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/The_Pentagon"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "An Peinteag\u00e1n",
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://ga.dbpedia.org/resource/An_Peinteag\u00e1n"
#                }
#             },
#             "http://dbpedia.org/ontology/abstract": "El Pent\u00e0gon (en angl\u00e8s The Pentagon) \u00e9s la seu del Departament de Defensa dels Estats Units, localitzat al Comtat d&#39;Arlington (Virg\u00ednia). Com a s\u00edmbol de l&#39;ex\u00e8rcit estatunidenc, el nom d&#39;&quot;El Pent\u00e0gon&quot; sovint s&#39;utilitza de manera meton\u00edmica per referir-se al Departament de Defensa que no pas a l&#39;edifici mateix. El seu nom prov\u00e9 de la seva forma pentagonal. Dissenyat per l&#39;arquitecte suec-estatunidenc (1876\u20141955) i constru\u00eft pel contractista general , l&#39;edifici fou dedicat el 15 de gener, 1943, dos anys despr\u00e9s que es comenc\u00e9s la construcci\u00f3 l&#39;11 de setembre, 1941. El Pent\u00e0gon \u00e9s un dels edificis m\u00e9s grans del m\u00f3n. Hi treballen 89.000 empleats militars i civils, i 3.000 altres empleats de suport. T\u00e9 cinc costats, cinc pisos sobre terra (i dos de sota), i cinc corredors per pis, un total de 28,2 km de corredors. La pla\u00e7a central d&#39;El Pent\u00e0gon t\u00e9 la forma, \u00e9s clar, d&#39;un pent\u00e0gon i t\u00e9 una superf\u00edcie de cinc acres (\u00e9s a dir, 20.000 m\u00b2). L&#39;espai obert \u00e9s al centre, que tamb\u00e9 t\u00e9 la forma d&#39;un pent\u00e0gon es coneix informalment com a ground zero, un terme que s&#39;origin\u00e0 durant la Guerra Freda, basat en la suposici\u00f3 que la Uni\u00f3 Sovi\u00e8tica hi llen\u00e7aria un o m\u00e9s m\u00edssils nuclears. Finalment, El Pent\u00e0gon est\u00e0 envoltat per la xarxa de carreteres del Pent\u00e0gon. El 1991 uns adolescents neerlandesos van hackejar els ordinadors canviant informaci\u00f3 classificada.",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Ronald_Reagan_Washington_National_Airport"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://www.w3.org/2002/07/owl#Thing"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:Use_dmy_dates"
#                }
#             },
#             "http://dbpedia.org/ontology/cost": "8.3E7",
#             "http://dbpedia.org/ontology/wikiPageExternalLink": {
#                "__deferred": {
#                   "uri": "https://web.archive.org/web/20050207185031/http:/www.pfpa.mil/"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:The_Pentagon"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Pentagon \u00e4r den byggnad d\u00e4r USA:s f\u00f6rsvarsdepartement har sitt s\u00e4te. Byggnaden ligger i Arlington County i delstaten Virginia vid floden Potomac n\u00e4ra gr\u00e4nsen till Washington, DC. \u00c4ven om Pentagon inte fysiskt ligger inom Columbiadistriktets gr\u00e4nser \u00e4r postorten \u00e4nd\u00e5 \u201dWashington, DC\u201d. Pentagon \u00e4r ansluten till Washingtons tunnelbana med en egen station.",
#             "http://dbpedia.org/property/mapCaption": "Location in the Washington, D.C. area",
#             "http://schema.org/sameAs": {
#                "__deferred": {
#                   "uri": "http://viaf.org/viaf/640144783176054589415"
#                }
#             },
#             "http://dbpedia.org/property/totalWidth": "800",
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/The_Pentagon?oldid=1024362057&ns=0"
#                }
#             },
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Headquarters"
#                }
#             },
#             "http://dbpedia.org/ontology/architect": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/George_Bergstrom"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "20740978",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#lat": "38.87094497680664",
#             "http://dbpedia.org/property/architect": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/George_Bergstrom"
#                }
#             },
#             "http://dbpedia.org/property/owner": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/United_States_Department_of_Defense"
#                }
#             },
#             "http://dbpedia.org/property/startDate": "1941-09-11",
#             "http://dbpedia.org/property/caption": "Security video of crash of Flight 77",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#long": "-77.05525207519531",
#             "http://dbpedia.org/ontology/status": "Finished",
#             "http://dbpedia.org/ontology/height": "21.6408",
#             "http://dbpedia.org/property/floorCount": "7",
#             "http://dbpedia.org/ontology/Building/floorArea": "616538.0185344",
#             "http://www.w3.org/2004/02/skos/core#exactMatch": {
#                "__deferred": {
#                   "uri": "http://globalwordnet.org/ili/i57136"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/depiction": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/The_Pentagon_January_2008.jpg"
#                }
#             },
#             "http://dbpedia.org/property/image": "DN-SD-03-11451.JPEG",
#             "http://xmlns.com/foaf/0.1/name": "The Pentagon",
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "1024362057",
#             "http://dbpedia.org/property/completionDate": "1943-01-15",
#             "http://dbpedia.org/property/architecturalStyle": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Stripped_Classicism"
#                }
#             },
#             "http://dbpedia.org/property/wordnet_type": {
#                "__deferred": {
#                   "uri": "http://www.w3.org/2006/03/wn/wn20/instances/synset-location-noun-1"
#                }
#             },
#             "http://dbpedia.org/property/topFloor": "5",
#             "http://dbpedia.org/property/location": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Arlington_County,_Virginia"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "43949",
#             "http://dbpedia.org/ontology/location": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Arlington_County,_Virginia"
#                }
#             },
#             "http://dbpedia.org/property/captionAlign": "center",
#             "http://dbpedia.org/property/direction": "horizontal",
#             "http://dbpedia.org/ontology/owner": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/United_States_Department_of_Defense"
#                }
#             },
#             "http://dbpedia.org/property/name": "The Pentagon",
#             "http://dbpedia.org/property/cost": "8.3E7",
#             "http://dbpedia.org/ontology/thumbnail": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/The_Pentagon_January_2008.jpg?width=300"
#                }
#             },
#             "http://www.w3.org/2003/01/geo/wgs84_pos#geometry": "POINT(-77.055252075195 38.870944976807)",
#             "http://www.georss.org/georss/point": "38.8709455 -77.0552551",
#             "http://dbpedia.org/ontology/architecturalStyle": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Stripped_Classicism"
#                }
#             },
#             "http://dbpedia.org/property/mainContractor": "John McShain, Inc.",
#             "http://dbpedia.org/property/imageSize": "240",
#             "http://dbpedia.org/property/references": "--04-18",
#             "http://dbpedia.org/ontology/floorArea": "616538.0185344",
#             "http://dbpedia.org/ontology/floorCount": "7",
#             "http://dbpedia.org/property/status": "Finished",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/The_Pentagon"
#                }
#             },
#             "http://dbpedia.org/property/mapType": "United States District of Columbia street",
#             "http://dbpedia.org/property/align": "center"
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ### Recuperando a página da Wikipédia usando Python

# %%
link = office_dbpedia["d"]["results"][0]["http://xmlns.com/foaf/0.1/isPrimaryTopicOf"]["__deferred"]["uri"]
print("Página da Wikipédia: " + link)
# Out:
# Página da Wikipédia: http://en.wikipedia.org/wiki/The_Pentagon
